# %%
from langgraph.graph import StateGraph, START, END
from typing import Literal
import random 
from IPython.display import Image, display
from typing_extensions import TypedDict
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 4
#       2 from typing import Literal
#       3 import random
# ----> 4 from IPython.display import Image, display, MermaidDrawMethod
#       5 from typing_extensions import TypedDict
#
# ImportError: cannot import name 'MermaidDrawMethod' from 'IPython.display' (C:\Users\srika\AppData\Roaming\Python\Python313\site-packages\IPython\display.py)

# %%
class State(TypedDict):
    graph_state: str

# %%
# Will be used as conditional edge 
def decide_mood(state : State) -> Literal["happy", "sad"]:
    # Here, let's just do a 50 / 50 split between nodes 2, 3
    if random.random() < 0.5:
        # 50% of the time, we return Node 2
        return "happy"
    
    # 50% of the time, we return Node 3
    return "sad"

# %%
def node_1(state):
    print("---Node 1---")
    return {"graph_state": state['graph_state'] +" I am"}

def node_2(state):
    print("---Node 2---")
    return {"graph_state": state['graph_state'] +" happy!"}

def node_3(state):
    print("---Node 3---")
    return {"graph_state": state['graph_state'] +" sad!"}

# %%
# Build graph
builder = StateGraph(State)
builder.add_node("node_1", node_1)
builder.add_node("happy", node_2)
builder.add_node("sad", node_3)

# %%
# Configure the flow of nodes
builder.add_edge(START, "node_1")
builder.add_conditional_edges("node_1", decide_mood)
builder.add_edge("happy", END)
builder.add_edge("sad", END)

# %%
# create graph
graph = builder.compile()

# %%
# View
display(Image(graph.get_graph().draw_mermaid_png()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # View
# ----> 2 display(Image(graph.get_graph().draw_mermaid_png()))
#
# File c:\python\Lib\site-packages\langchain_core\runnables\graph.py:693, in Graph.draw_mermaid_png(self, curve_style, node_colors, wrap_label_n_words, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, frontmatter_config, base_url, proxies)
#     683 from langchain_core.runnables.graph_mermaid import (  # noqa: PLC0415
#     684     draw_mermaid_png,
#     685 )
#     687 mermaid_syntax = self.draw_mermaid(
#     688     curve_style=curve_style,
#     689     node_colors=node_colors,
#     690     wrap_label_n_words=wrap_label_n_words,
#     691     frontmatter_config=frontmatter_config,
#     692 )
# --> 693 return draw_mermaid_png(
#     694     mermaid_syntax=mermaid_syntax,
#     695     output_file_path=output_file_path,
#     696     draw_method=draw_method,
#     697     background_color=background_color,
#     698     padding=padding,
#     699     max_retries=max_retries,
#     700     retry_delay=retry_delay,
#     701     proxies=proxies,
#     702     base_url=base_url,
#     703 )
#
# File c:\python\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:312, in draw_mermaid_png(mermaid_syntax, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, base_url, proxies)
#     306     img_bytes = asyncio.run(
#     307         _render_mermaid_using_pyppeteer(
#     308             mermaid_syntax, output_file_path, background_color, padding
#     309         )
#     310     )
#     311 elif draw_method == MermaidDrawMethod.API:
# --> 312     img_bytes = _render_mermaid_using_api(
#     313         mermaid_syntax,
#     314         output_file_path=output_file_path,
#     315         background_color=background_color,
#     316         max_retries=max_retries,
#     317         retry_delay=retry_delay,
#     318         base_url=base_url,
#     319         proxies=proxies,
#     320     )
#     321 else:
#     322     supported_methods = ", ".join([m.value for m in MermaidDrawMethod])
#
# File c:\python\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:475, in _render_mermaid_using_api(mermaid_syntax, output_file_path, background_color, file_type, max_retries, retry_delay, proxies, base_url)
#     470     # For other status codes, fail immediately
#     471     msg = (
#     472         f"Failed to reach {base_url} API while trying to render "
#     473         f"your graph. Status code: {response.status_code}.\n\n"
#     474     ) + error_msg_suffix
# --> 475     raise ValueError(msg)
#     477 except (requests.RequestException, requests.Timeout) as e:
#     478     if attempt < max_retries:
#     479         # Exponential backoff with jitter
#
# ValueError: Failed to reach https://mermaid.ink API while trying to render your graph. Status code: 400.
#
# To resolve this issue:
# 1. Check your internet connection and try again
# 2. Try with higher retry settings: `draw_mermaid_png(..., max_retries=5, retry_delay=2.0)`
# 3. Use the Pyppeteer rendering method which will render your graph locally in a browser: `draw_mermaid_png(..., draw_method=MermaidDrawMethod.PYPPETEER)`

# %%
result = graph.invoke({"graph_state" : "Hi, this is Srikanth."})
print(result)
# Out:
# ---Node 1---
# ---Node 3---
# {'graph_state': 'Hi, this is Srikanth. I am sad!'}
