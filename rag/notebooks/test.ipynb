# %%
import datetime

# %%
print(datetime.datetime.now())

# %% [markdown]
# ### Use methods of date

# %%
name = input("Enter your name :")

# %%
print(name)

# %%
if name == 'end':
        print('The End')
else:
  print("Name = ", name)

# %%
print('Over')
